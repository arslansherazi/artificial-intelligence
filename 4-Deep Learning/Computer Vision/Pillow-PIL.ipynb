# %% [markdown]
# # Pillow - Python Image Library
# <b> open image in preview window </b>
# - image.show()
#
# <b> save image </b>
# - file_path = 'outputs/thumbnail_butterfly.jpeg'
# - image.save(file_path)

# %%
from PIL import Image

# %% [markdown]
# ### Open an Image

# %%
image = Image.open('images/cv-image4.jpeg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=245x206 at 0x7FC7B295AE10>

# %% [markdown]
# ### Rotate an Image

# %%
image.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=245x206 at 0x7FC7B27C3850>

# %% [markdown]
# ### Attributes of Image

# %%
image.filename
# Out:
# 'images/cv-image4.jpeg'

# %%
image.format
# Out:
# 'JPEG'

# %%
image.mode
# Out:
# 'RGB'

# %%
image.size
# Out:
# (245, 206)

# %%
image.width
# Out:
# 245

# %%
image.height
# Out:
# 206

# %%
image.info
# Out:
# {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1)}

# %%
image.palette

# %% [markdown]
# ### Change size of file
# - size of resized image cannot be larger than image original size

# %%
image.thumbnail((180, 180))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=180x151 at 0x7FC7B295AE10>
