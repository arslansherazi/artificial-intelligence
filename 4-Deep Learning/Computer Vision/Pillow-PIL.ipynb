# %% [markdown]
# # Pillow - Python Image Library
# <b> open image in preview window </b>
# - image.show()

# %%
from PIL import Image

# %% [markdown]
# ### Open an Image

# %%
image = Image.open('images/cv-image4.jpeg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=245x206 at 0x7F90DB60C950>

# %% [markdown]
# ### Rotate an Image

# %%
image.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=245x206 at 0x7F90DB604D90>

# %% [markdown]
# ### Attributes of Image

# %%
image.filename
# Out:
# 'images/cv-image4.jpeg'

# %%
image.format
# Out:
# 'JPEG'

# %%
image.mode
# Out:
# 'RGB'

# %%
image.size
# Out:
# (245, 206)

# %%
image.width
# Out:
# 245

# %%
image.height
# Out:
# 206

# %%
image.info
# Out:
# {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1)}

# %%
image.palette
