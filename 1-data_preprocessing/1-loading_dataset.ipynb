# %% [markdown]
# # Loading Dataset by Skipping Unnecessary Data

# %% [markdown]
# * skiprows is used to skip specified no of rows from start
# * skipfooter is used to skip specified no of rows from bottom
# * engine='python' is necessary for using skipfooter
# * sep='\s+' is used to separate values by space

# %%
import pandas as pd

# %%
df = pd.read_csv("../datasets/temperatures.txt", sep='\s+', skiprows=7, skipfooter=11, engine='python')

# %%
df.head()
# Out:
#    Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  J-D  D-N  \
# 0  1880  -34  -27  -22  -30  -16  -24  -19  -12  -20  -19  -16  -21  -22  ***
# 1  1881  -13  -16   -2   -3   -3  -27  -12   -8  -18  -23  -28  -18  -14  -14
# 2  1882    3    4   -2  -24  -20  -32  -27  -11  -11  -25  -25  -37  -17  -16
# 3  1883  -38  -38  -12  -20  -20   -8   -3  -13  -19  -19  -28  -21  -20  -21
# 4  1884  -20  -14  -31  -36  -33  -36  -31  -24  -29  -25  -29  -25  -28  -28
#
#     DJF  MAM  JJA  SON Year.1
# 0  ****  -23  -18  -18   1880
# 1   -17   -3  -15  -23   1881
# 2    -4  -15  -23  -20   1882
# 3   -38  -18   -8  -22   1883
# 4   -18  -33  -31  -28   1884

# %% [markdown]
# # Loading Dataset from CSV File

# %%
df = pd.read_csv("../datasets/admission_predictions.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admission
# 0         1                 0.92
# 1         1                 0.76
# 2         1                 0.72
# 3         1                 0.80
# 4         0                 0.65

# %% [markdown]
# ### Making column as index column instead of default indexes(0 to length(rows)-1)

# %%
df = df.set_index("Serial No.",drop=True)

# %%
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admission
# Serial No.
# 1                  1                 0.92
# 2                  1                 0.76
# 3                  1                 0.72
# 4                  1                 0.80
# 5                  0                 0.65

# %% [markdown]
# # Loading Dataset from Database

# %%
import mysql.connector as sql

# %%
connection = sql.connect(host='localhost', port=3306, database='ofd_db', user='root', password='rootroot')
query = "SELECT * FROM order_history"

# %%
dataset = pd.read_sql(query, connection, index_col='id')

# %%
dataset.head()
# Out:
#    order_number     status  price  discount  is_delivery  \
# id
# 2      55bdf6e5  Completed    800         0            1
# 3      30982326  Completed    800         0            1
# 4      1ca26f24  Completed   1200         0            1
# 5      582a129e  Completed   2200         0            1
# 6      56d4014e     Placed   1200         7            1
#
#          delivery_address  latitude  longitude  is_price_changed  \
# id
# 2    Muzaffar Pur Sialkot   12.2300    59.2300                 0
# 3    Muzaffar Pur Sialkot   12.2300    59.2300                 0
# 4    Muzaffar Pur Sialkot   12.2300    59.2300                 0
# 5   defence road, sialkot   32.4945    74.5229                 0
# 6    Muzaffar Pur Sialkot   12.2300    59.2300                 0
#
#                  created_date               updated_date  buyer_id  \
# id
# 2  2020-05-03 12:30:50.030768 2020-05-03 12:30:50.030822         1
# 3  2020-05-03 13:27:35.462236 2020-05-03 13:27:35.462292         1
# 4  2020-05-03 17:37:26.263438 2020-05-03 17:37:26.263505         1
# 5  2020-05-03 17:52:35.227804 2020-05-03 17:52:35.227867         1
# 6  2020-05-03 17:54:03.100679 2020-05-03 17:54:03.100749         1
#
#     merchant_id
# id
# 2             2
# 3             2
# 4             2
# 5             2
# 6             2

# %% [markdown]
# # Loading Dataset from Html Page

# %%
tables = pd.read_html("http://www.psmsl.org/data/obtaining/")

# %%
dataset = tables[0]

# %%
dataset.head()
# Out:
#   Station Name  ID    Lat.    Lon.  GLOSS ID Country        Date  Coastline  \
# 0        BREST   1  48.383  -4.495     242.0     FRA  07/08/2019        190
# 1  SWINOUJSCIE   2  53.917  14.233       NaN     POL  19/10/2001        110
# 2    SHEERNESS   3  51.446   0.743       NaN     GBR  06/06/2019        170
# 3     HOLYHEAD   5  53.314  -4.620       NaN     GBR  06/06/2019        170
# 4   CUXHAVEN 2   7  53.867   8.717     284.0     DEU  01/10/2019        140
#
#    Station
# 0       91
# 1       92
# 2      101
# 3      191
# 4       12

# %% [markdown]
# # Loading Dataset from Remote Location

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/balance-scale/balance-scale.data", sep=",")
df.columns = ['Balance Scale','Left Weight','Left Distance','Right Weight','Right Distance']

# %%
df.head()
# Out:
#   Balance Scale  Left Weight  Left Distance  Right Weight  Right Distance
# 0             R            1              1             1               2
# 1             R            1              1             1               3
# 2             R            1              1             1               4
# 3             R            1              1             1               5
# 4             R            1              1             2               1

# %% [markdown]
# # Loading Dataset from Text File

# %%
df = pd.read_csv("../Datasets/car_evaluation.txt", sep=",")
df.columns = ['buying','maintenance','doors','persons','lug_boot','safety','class']

# %%
df.head()
# Out:
#   buying maintenance doors persons lug_boot safety  class
# 0  vhigh       vhigh     2       2    small    med  unacc
# 1  vhigh       vhigh     2       2    small   high  unacc
# 2  vhigh       vhigh     2       2      med    low  unacc
# 3  vhigh       vhigh     2       2      med    med  unacc
# 4  vhigh       vhigh     2       2      med   high  unacc
